# %% [markdown]
# <a href="https://colab.research.google.com/github/pushyag1/NLPClass/blob/master/Text_Summary_and_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercise 1. Text Summary
#
# • Use the ‘spaceX_DP.txt’ file in DATA 690 Data Files.
#
# • Import 'spacy' for stopwords and 'string' for punctuation.
#
# • Tokenize the 'SpaceX.txt' corpus.
#
# • Build 'word frequency'. Make sure you have removed the stopwords.
#
# • Determine the maximum frequency as 'word_frequencies[word]=
# (word_frequencies[word]/maximum_frequency).
#
# • Tokenize the sentences. Generate the sentence_scores. Score every sentence
# based on number of words.
#
# • Import nlargest from heapq and provide 'summarized_sentences'.
#
# • Convert sentences from spacy to strings and join all sentences.
#
# • Provide a summary once you have converted spacy outputs to strings.
#
# • Determine the length of the summary.
#
# • Determine the length of the original text.
#
# • Install gensim_sum_ext to summarize the original test and compare with spacy's
# output.
#
# • Print the summary in 250 words.

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import pandas as pd
import re

# %%
import string

# %%
from string import punctuation

# %%
file=open('spaceX_DP.txt','r',encoding='UTF-8')
file1= file.read()

# %%
file1
# Out:
# 'Cape Canaveral this is not.But here, down toward the coast, on a spit of land past the Border Patrol checkpoint, where the Rio Grande meets the Gulf of Mexico, there is a spaceship being assembled off State Highway 4 just before it dead-ends into the sea.Towering and stainless-steel shiny, it looks like a surreal sculpture amid the cactuses, yucca and relentless South Texas sun. And, because it’s being built not in a factory but out in the open, it’s become a roadside attraction, drawing gawkers to an area so remote that the county trucks in drinking water once a month to the few who live nearby.They’re coming to see Elon Musk’s latest creation, a prototype called Starship that he hopes will one day carry people by the dozens to the moon and Mars. Musk, in a presentation here Saturday, said his goal of building a “rapidly reusable spacecraft” here would lead to the fulfillment of his ultimate goal of creating “a city on Mars.” But first, he’ll need to pull off another improbable feat, building a private, commercial spaceport here, in what the top local elected official called a “mind-boggling” juxtaposition: SpaceX, one of the hottest companies in the world, led by a Silicon Valley celebrity with nearly 29 million Twitter followers, building a rocket in a border town where nearly a third of the residents live below the poverty line.“I never in a million years would have imagined it,” said Cameron County Judge Eddie Treviño Jr. Five years ago, SpaceX started building a launchpad here, hauling in dirt by the ton, that would allow the company a measure of freedom without the restraints that come with shooting rockets off from government sites, such as Cape Canaveral or Vandenberg Air Force Base in California, where several other companies operate. “This is really going to be a new kind of spaceport that is optimized for commercial operations,” Musk said during a groundbreaking ceremony in 2014. “Cape Canaveral and Cape Vandenberg are great launch sites, but they are military launch sites.”The company has been welcomed by local officials as a Walt Disney-like messiah that would help spark an economic revival in an area that desperately needs it. The state set aside $15.3 million to help the company build its facilities here and has bought into SpaceX’s vision to transform the area into a commercial spaceport that would be sending people throughout the solar system.“You know the term ‘visionary’; they’re the ones who make the world go \'round,” Treviño said. Outside the county courthouse, the downtown here is replete with boarded-up businesses. Real estate prices are depressed. Schools are surrounded by security fences. For years, the area has been caught in an unending “vicious cycle,” Treviño said, so bad that people who “are fortunate to get a college education or a postgraduate degree don’t come back.” While he knows SpaceX’s presence has led to “growing pains,” he said those are merely the turbulent spasms of progress in an area that has seen very little. But now, across the water on South Padre Island, the county has spent about $31 million building new pavilions and an amphitheater that would host concerts and weddings and make a prime viewing area for rocket launches. Local officials hope for a future where residents and tourists line the beach, the way they have for years along Florida’s Space Coast, cheering rockets as they tear through the sky.“It’s exciting,” said Sofia Benavides, a county commissioner who represents Boca Chica. “I’m 69 years old and have never been to a rocket launch. For my children and grandchildren, it’s great that this is happening in their backyard.” Not everyone is cheering, though. A handful of residents who live next door to SpaceX’s facilities recently received letters from SpaceX, which said the company’s footprint in the area was going to be bigger and more disruptive than originally imagined. As a result, it was seeking to purchase their properties at three times the value determined by an ...

# %%
from string import punctuation

# %%
remove_Sent = re.sub('[^A-Za-z0-9]+', ' ', file1)
remove_Sent
# Out:
# 'Cape Canaveral this is not But here down toward the coast on a spit of land past the Border Patrol checkpoint where the Rio Grande meets the Gulf of Mexico there is a spaceship being assembled off State Highway 4 just before it dead ends into the sea Towering and stainless steel shiny it looks like a surreal sculpture amid the cactuses yucca and relentless South Texas sun And because it s being built not in a factory but out in the open it s become a roadside attraction drawing gawkers to an area so remote that the county trucks in drinking water once a month to the few who live nearby They re coming to see Elon Musk s latest creation a prototype called Starship that he hopes will one day carry people by the dozens to the moon and Mars Musk in a presentation here Saturday said his goal of building a rapidly reusable spacecraft here would lead to the fulfillment of his ultimate goal of creating a city on Mars But first he ll need to pull off another improbable feat building a private commercial spaceport here in what the top local elected official called a mind boggling juxtaposition SpaceX one of the hottest companies in the world led by a Silicon Valley celebrity with nearly 29 million Twitter followers building a rocket in a border town where nearly a third of the residents live below the poverty line I never in a million years would have imagined it said Cameron County Judge Eddie Trevi o Jr Five years ago SpaceX started building a launchpad here hauling in dirt by the ton that would allow the company a measure of freedom without the restraints that come with shooting rockets off from government sites such as Cape Canaveral or Vandenberg Air Force Base in California where several other companies operate This is really going to be a new kind of spaceport that is optimized for commercial operations Musk said during a groundbreaking ceremony in 2014 Cape Canaveral and Cape Vandenberg are great launch sites but they are military launch sites The company has been welcomed by local officials as a Walt Disney like messiah that would help spark an economic revival in an area that desperately needs it The state set aside 15 3 million to help the company build its facilities here and has bought into SpaceX s vision to transform the area into a commercial spaceport that would be sending people throughout the solar system You know the term visionary they re the ones who make the world go round Trevi o said Outside the county courthouse the downtown here is replete with boarded up businesses Real estate prices are depressed Schools are surrounded by security fences For years the area has been caught in an unending vicious cycle Trevi o said so bad that people who are fortunate to get a college education or a postgraduate degree don t come back While he knows SpaceX s presence has led to growing pains he said those are merely the turbulent spasms of progress in an area that has seen very little But now across the water on South Padre Island the county has spent about 31 million building new pavilions and an amphitheater that would host concerts and weddings and make a prime viewing area for rocket launches Local officials hope for a future where residents and tourists line the beach the way they have for years along Florida s Space Coast cheering rockets as they tear through the sky It s exciting said Sofia Benavides a county commissioner who represents Boca Chica I m 69 years old and have never been to a rocket launch For my children and grandchildren it s great that this is happening in their backyard Not everyone is cheering though A handful of residents who live next door to SpaceX s facilities recently received letters from SpaceX which said the company s footprint in the area was going to be bigger and more disruptive than originally imagined As a result it was seeking to purchase their properties at three times the value determined by an appraiser hired by SpaceX The deal was nonnegotiable the letter said and the company wanted a ...

# %%
mult = re.sub("\s\s+", " ", remove_Sent)
mult
# Out:
# 'Cape Canaveral this is not But here down toward the coast on a spit of land past the Border Patrol checkpoint where the Rio Grande meets the Gulf of Mexico there is a spaceship being assembled off State Highway 4 just before it dead ends into the sea Towering and stainless steel shiny it looks like a surreal sculpture amid the cactuses yucca and relentless South Texas sun And because it s being built not in a factory but out in the open it s become a roadside attraction drawing gawkers to an area so remote that the county trucks in drinking water once a month to the few who live nearby They re coming to see Elon Musk s latest creation a prototype called Starship that he hopes will one day carry people by the dozens to the moon and Mars Musk in a presentation here Saturday said his goal of building a rapidly reusable spacecraft here would lead to the fulfillment of his ultimate goal of creating a city on Mars But first he ll need to pull off another improbable feat building a private commercial spaceport here in what the top local elected official called a mind boggling juxtaposition SpaceX one of the hottest companies in the world led by a Silicon Valley celebrity with nearly 29 million Twitter followers building a rocket in a border town where nearly a third of the residents live below the poverty line I never in a million years would have imagined it said Cameron County Judge Eddie Trevi o Jr Five years ago SpaceX started building a launchpad here hauling in dirt by the ton that would allow the company a measure of freedom without the restraints that come with shooting rockets off from government sites such as Cape Canaveral or Vandenberg Air Force Base in California where several other companies operate This is really going to be a new kind of spaceport that is optimized for commercial operations Musk said during a groundbreaking ceremony in 2014 Cape Canaveral and Cape Vandenberg are great launch sites but they are military launch sites The company has been welcomed by local officials as a Walt Disney like messiah that would help spark an economic revival in an area that desperately needs it The state set aside 15 3 million to help the company build its facilities here and has bought into SpaceX s vision to transform the area into a commercial spaceport that would be sending people throughout the solar system You know the term visionary they re the ones who make the world go round Trevi o said Outside the county courthouse the downtown here is replete with boarded up businesses Real estate prices are depressed Schools are surrounded by security fences For years the area has been caught in an unending vicious cycle Trevi o said so bad that people who are fortunate to get a college education or a postgraduate degree don t come back While he knows SpaceX s presence has led to growing pains he said those are merely the turbulent spasms of progress in an area that has seen very little But now across the water on South Padre Island the county has spent about 31 million building new pavilions and an amphitheater that would host concerts and weddings and make a prime viewing area for rocket launches Local officials hope for a future where residents and tourists line the beach the way they have for years along Florida s Space Coast cheering rockets as they tear through the sky It s exciting said Sofia Benavides a county commissioner who represents Boca Chica I m 69 years old and have never been to a rocket launch For my children and grandchildren it s great that this is happening in their backyard Not everyone is cheering though A handful of residents who live next door to SpaceX s facilities recently received letters from SpaceX which said the company s footprint in the area was going to be bigger and more disruptive than originally imagined As a result it was seeking to purchase their properties at three times the value determined by an appraiser hired by SpaceX The deal was nonnegotiable the letter said and the company wanted a ...

# %%
from spacy.lang.en import English

# %%
nlp = English()

# %%
my_doc = nlp(file2)

# %%
# Create list of word tokens
token_list = []
for token in my_doc:
    token_list.append(token.text)

# %%
#from spacy.lang.en.stop_words import STOP_WORDS

# Create list of word tokens after removing stopwords
filtered_sentence =[] 

for word in token_list:
    lexeme = nlp.vocab[word]
    if lexeme.is_stop == False:
        filtered_sentence.append(word) 
print(token_list)
print(filtered_sentence)
# Out:
# ['Cape', 'Canaveral', 'this', 'is', 'not', 'But', 'here', ' ', 'down', 'toward', 'the', 'coast', ' ', 'on', 'a', 'spit', 'of', 'land', 'past', 'the', 'Border', 'Patrol', 'checkpoint', ' ', 'where', 'the', 'Rio', 'Grande', 'meets', 'the', 'Gulf', 'of', 'Mexico', ' ', 'there', 'is', 'a', 'spaceship', 'being', 'assembled', 'off', 'State', 'Highway', '4', 'just', 'before', 'it', 'dead', '-', 'ends', 'into', 'the', 'sea', 'Towering', 'and', 'stainless', '-', 'steel', 'shiny', ' ', 'it', 'looks', 'like', 'a', 'surreal', 'sculpture', 'amid', 'the', 'cactuses', ' ', 'yucca', 'and', 'relentless', 'South', 'Texas', 'sun', ' ', 'And', ' ', 'because', 'it', 's', 'being', 'built', 'not', 'in', 'a', 'factory', 'but', 'out', 'in', 'the', 'open', ' ', 'it', 's', 'become', 'a', 'roadside', 'attraction', ' ', 'drawing', 'gawkers', 'to', 'an', 'area', 'so', 'remote', 'that', 'the', 'county', 'trucks', 'in', 'drinking', 'water', 'once', 'a', 'month', 'to', 'the', 'few', 'who', 'live', 'nearby', 'They', 're', 'coming', 'to', 'see', 'Elon', 'Musk', 's', 'latest', 'creation', ' ', 'a', 'prototype', 'called', 'Starship', 'that', 'he', 'hopes', 'will', 'one', 'day', 'carry', 'people', 'by', 'the', 'dozens', 'to', 'the', 'moon', 'and', 'Mars', ' ', 'Musk', ' ', 'in', 'a', 'presentation', 'here', 'Saturday', ' ', 'said', 'his', 'goal', 'of', 'building', 'a', ' ', 'rapidly', 'reusable', 'spacecraft', ' ', 'here', 'would', 'lead', 'to', 'the', 'fulfillment', 'of', 'his', 'ultimate', 'goal', 'of', 'creating', ' ', 'a', 'city', 'on', 'Mars', '  ', 'But', 'first', ' ', 'he', 'll', 'need', 'to', 'pull', 'off', 'another', 'improbable', 'feat', ' ', 'building', 'a', 'private', ' ', 'commercial', 'spaceport', 'here', ' ', 'in', 'what', 'the', 'top', 'local', 'elected', 'official', 'called', 'a', ' ', 'mind', '-', 'boggling', ' ', 'juxtaposition', ':', 'SpaceX', ' ', 'one', 'of', 'the', 'hottest', 'companies', 'in', 'the', 'world', ' ', 'led', 'by', 'a', 'Silicon', 'Valley', 'celebrity', 'with', 'nearly', '29', 'million', 'Twitter', 'followers', ' ', 'building', 'a', 'rocket', 'in', 'a', 'border', 'town', 'where', 'nearly', 'a', 'third', 'of', 'the', 'residents', 'live', 'below', 'the', 'poverty', 'line', ' ', 'I', 'never', 'in', 'a', 'million', 'years', 'would', 'have', 'imagined', 'it', '  ', 'said', 'Cameron', 'County', 'Judge', 'Eddie', 'Treviño', 'Jr', ' ', 'Five', 'years', 'ago', ' ', 'SpaceX', 'started', 'building', 'a', 'launchpad', 'here', ' ', 'hauling', 'in', 'dirt', 'by', 'the', 'ton', ' ', 'that', 'would', 'allow', 'the', 'company', 'a', 'measure', 'of', 'freedom', 'without', 'the', 'restraints', 'that', 'come', 'with', 'shooting', 'rockets', 'off', 'from', 'government', 'sites', ' ', 'such', 'as', 'Cape', 'Canaveral', 'or', 'Vandenberg', 'Air', 'Force', 'Base', 'in', 'California', ' ', 'where', 'several', 'other', 'companies', 'operate', '  ', 'This', 'is', 'really', 'going', 'to', 'be', 'a', 'new', 'kind', 'of', 'spaceport', 'that', 'is', 'optimized', 'for', 'commercial', 'operations', '  ', 'Musk', 'said', 'during', 'a', 'groundbreaking', 'ceremony', 'in', '2014', '  ', 'Cape', 'Canaveral', 'and', 'Cape', 'Vandenberg', 'are', 'great', 'launch', 'sites', ' ', 'but', 'they', 'are', 'military', 'launch', 'sites', ' ', 'The', 'company', 'has', 'been', 'welcomed', 'by', 'local', 'officials', 'as', 'a', 'Walt', 'Disney', '-', 'like', 'messiah', 'that', 'would', 'help', 'spark', 'an', 'economic', 'revival', 'in', 'an', 'area', 'that', 'desperately', 'needs', 'it', ' ', 'The', 'state', 'set', 'aside', '$', '15', '3', 'million', 'to', 'help', 'the', 'company', 'build', 'its', 'facilities', 'here', 'and', 'has', 'bought', 'into', 'SpaceX', 's', 'vision', 'to', 'transform', 'the', 'area', 'into', 'a', 'commercial', 'spaceport', 'that', 'would', 'be', 'sending', 'people', 'throughout', 'the', 'solar', 'system', ' ', 'You', 'know', 'the', 'term', '‘', 'visionary', ';', 'they', 're', 'the', 'ones', 'who', 'make', 'the', 'world', 'go', ' ', 'round', '  ', 'Trevi ...
# ['Cape', 'Canaveral', ' ', 'coast', ' ', 'spit', 'land', 'past', 'Border', 'Patrol', 'checkpoint', ' ', 'Rio', 'Grande', 'meets', 'Gulf', 'Mexico', ' ', 'spaceship', 'assembled', 'State', 'Highway', '4', 'dead', '-', 'ends', 'sea', 'Towering', 'stainless', '-', 'steel', 'shiny', ' ', 'looks', 'like', 'surreal', 'sculpture', 'amid', 'cactuses', ' ', 'yucca', 'relentless', 'South', 'Texas', 'sun', ' ', ' ', 's', 'built', 'factory', 'open', ' ', 's', 'roadside', 'attraction', ' ', 'drawing', 'gawkers', 'area', 'remote', 'county', 'trucks', 'drinking', 'water', 'month', 'live', 'nearby', 'coming', 'Elon', 'Musk', 's', 'latest', 'creation', ' ', 'prototype', 'called', 'Starship', 'hopes', 'day', 'carry', 'people', 'dozens', 'moon', 'Mars', ' ', 'Musk', ' ', 'presentation', 'Saturday', ' ', 'said', 'goal', 'building', ' ', 'rapidly', 'reusable', 'spacecraft', ' ', 'lead', 'fulfillment', 'ultimate', 'goal', 'creating', ' ', 'city', 'Mars', '  ', ' ', 'll', 'need', 'pull', 'improbable', 'feat', ' ', 'building', 'private', ' ', 'commercial', 'spaceport', ' ', 'local', 'elected', 'official', 'called', ' ', 'mind', '-', 'boggling', ' ', 'juxtaposition', ':', 'SpaceX', ' ', 'hottest', 'companies', 'world', ' ', 'led', 'Silicon', 'Valley', 'celebrity', 'nearly', '29', 'million', 'Twitter', 'followers', ' ', 'building', 'rocket', 'border', 'town', 'nearly', 'residents', 'live', 'poverty', 'line', ' ', 'million', 'years', 'imagined', '  ', 'said', 'Cameron', 'County', 'Judge', 'Eddie', 'Treviño', 'Jr', ' ', 'years', 'ago', ' ', 'SpaceX', 'started', 'building', 'launchpad', ' ', 'hauling', 'dirt', 'ton', ' ', 'allow', 'company', 'measure', 'freedom', 'restraints', 'come', 'shooting', 'rockets', 'government', 'sites', ' ', 'Cape', 'Canaveral', 'Vandenberg', 'Air', 'Force', 'Base', 'California', ' ', 'companies', 'operate', '  ', 'going', 'new', 'kind', 'spaceport', 'optimized', 'commercial', 'operations', '  ', 'Musk', 'said', 'groundbreaking', 'ceremony', '2014', '  ', 'Cape', 'Canaveral', 'Cape', 'Vandenberg', 'great', 'launch', 'sites', ' ', 'military', 'launch', 'sites', ' ', 'company', 'welcomed', 'local', 'officials', 'Walt', 'Disney', '-', 'like', 'messiah', 'help', 'spark', 'economic', 'revival', 'area', 'desperately', 'needs', ' ', 'state', 'set', 'aside', '$', '15', '3', 'million', 'help', 'company', 'build', 'facilities', 'bought', 'SpaceX', 's', 'vision', 'transform', 'area', 'commercial', 'spaceport', 'sending', 'people', 'solar', 'system', ' ', 'know', 'term', '‘', 'visionary', ';', 'ones', 'world', ' ', 'round', '  ', 'Treviño', 'said', ' ', 'Outside', 'county', 'courthouse', ' ', 'downtown', 'replete', 'boarded', '-', 'businesses', ' ', 'Real', 'estate', 'prices', 'depressed', ' ', 'Schools', 'surrounded', 'security', 'fences', ' ', 'years', ' ', 'area', 'caught', 'unending', ' ', 'vicious', 'cycle', '  ', 'Treviño', 'said', ' ', 'bad', 'people', ' ', 'fortunate', 'college', 'education', 'postgraduate', 'degree', 'don', 't', 'come', '  ', 'knows', 'SpaceX', 's', 'presence', 'led', ' ', 'growing', 'pains', '  ', 'said', 'merely', 'turbulent', 'spasms', 'progress', 'area', 'seen', 'little', ' ', ' ', 'water', 'South', 'Padre', 'Island', ' ', 'county', 'spent', '$', '31', 'million', 'building', 'new', 'pavilions', 'amphitheater', 'host', 'concerts', 'weddings', 'prime', 'viewing', 'area', 'rocket', 'launches', ' ', 'Local', 'officials', 'hope', 'future', 'residents', 'tourists', 'line', 'beach', ' ', 'way', 'years', 'Florida', 's', 'Space', 'Coast', ' ', 'cheering', 'rockets', 'tear', 'sky', ' ', 's', 'exciting', '  ', 'said', 'Sofia', 'Benavides', ' ', 'county', 'commissioner', 'represents', 'Boca', 'Chica', '  ', 'm', '69', 'years', 'old', 'rocket', 'launch', ' ', 'children', 'grandchildren', ' ', 's', 'great', 'happening', 'backyard', '  ', 'cheering', ' ', ' ', 'handful', 'residents', 'live', 'door', 'SpaceX', 's', 'facilities', 'recently', 'received', 'letters', 'SpaceX', ' ', 'said', 'company', 's', 'footprint', 'area', 'goi ...

# %%
wordfreq = []
for w in filtered_sentence:
    wordfreq.append(filtered_sentence.count(w))

wordfreq

# %%
print("Frequencies\n" + str(wordfreq) + "\n")
print("Word_Frequencies\n" + str(list(zip(filtered_sentence, wordfreq))))
Word_Frequencies=str(list(zip(filtered_sentence, wordfreq)))
# Out:
# Frequencies
# [9, 8, 2017, 4, 2017, 2, 15, 8, 18, 3, 5, 2017, 9, 9, 1, 6, 7, 2017, 8, 4, 10, 14, 16, 2, 190, 1, 11, 1, 6, 190, 9, 1, 2017, 3, 35, 2, 1, 2, 1, 2017, 2, 1, 37, 76, 5, 2017, 2017, 211, 11, 2, 6, 2017, 211, 1, 2, 2017, 1, 1, 28, 2, 23, 7, 2, 14, 16, 9, 12, 1, 19, 85, 211, 5, 1, 2017, 22, 12, 67, 2, 24, 5, 30, 2, 10, 26, 2017, 85, 2017, 5, 5, 2017, 126, 3, 16, 2017, 2, 6, 15, 2017, 1, 1, 1, 3, 1, 2017, 6, 26, 306, 2017, 7, 6, 1, 3, 1, 2017, 16, 11, 2017, 14, 11, 2017, 21, 1, 5, 12, 2017, 6, 190, 1, 2017, 1, 29, 264, 2017, 2, 5, 10, 2017, 4, 1, 6, 1, 9, 9, 14, 5, 3, 2017, 16, 71, 11, 18, 9, 78, 9, 1, 5, 2017, 14, 33, 3, 306, 126, 14, 14, 1, 2, 8, 1, 2017, 33, 6, 2017, 264, 10, 16, 6, 2017, 1, 3, 1, 2017, 7, 89, 1, 2, 1, 17, 1, 18, 7, 5, 2017, 9, 8, 4, 2, 2, 2, 5, 2017, 5, 2, 306, 36, 54, 8, 11, 1, 14, 12, 306, 85, 126, 2, 2, 15, 306, 9, 8, 9, 4, 3, 70, 5, 2017, 2, 70, 5, 2017, 89, 1, 21, 16, 1, 1, 190, 35, 1, 6, 2, 7, 1, 28, 1, 7, 2017, 14, 4, 1, 25, 3, 10, 14, 6, 89, 15, 9, 9, 264, 211, 7, 1, 28, 14, 11, 4, 30, 3, 7, 2017, 10, 3, 8, 2, 30, 1, 10, 2017, 6, 306, 8, 126, 2017, 1, 23, 1, 2017, 1, 1, 2, 190, 1, 2017, 1, 3, 2, 2, 2017, 1, 1, 4, 1, 2017, 33, 2017, 28, 5, 1, 2017, 1, 1, 306, 8, 126, 2017, 3, 30, 2017, 2, 7, 2, 1, 1, 15, 78, 17, 306, 5, 264, 211, 5, 4, 2017, 4, 1, 306, 126, 1, 1, 1, 2, 28, 6, 6, 2017, 2017, 14, 37, 11, 12, 2017, 23, 4, 25, 2, 14, 16, 54, 1, 2, 2, 1, 1, 2, 3, 28, 71, 20, 2017, 2, 16, 2, 9, 78, 2, 5, 26, 2017, 19, 33, 6, 211, 14, 3, 2017, 2, 18, 1, 8, 2017, 211, 4, 306, 126, 1, 1, 2017, 23, 1, 1, 118, 110, 306, 14, 1, 33, 6, 71, 70, 2017, 1, 1, 2017, 211, 3, 1, 5, 306, 2, 2017, 2017, 1, 78, 9, 5, 264, 211, 9, 5, 12, 6, 264, 2017, 126, 89, 211, 1, 28, 36, 1, 4, 4, 3, 2017, 1, 2017, 5, 1, 8, 16, 4, 3, 2, 4, 264, 2017, 5, 1, 2017, 25, 126, 2017, 89, 15, 1, 7, 2017, 12, 1, 2017, 1, 118, 110, 17, 2017, 28, 2, 24, 1, 3, 6, 7, 2017, 1, 1, 2017, 2, 2017, 1, 8, 1, 2017, 190, 34, 78, 12, 5, 5, 190, 190, 190, 15, 3, 2017, 211, 2, 85, 1, 6, 2, 5, 2, 1, 2, 2017, 1, 6, 7, 26, 2017, 211, 1, 14, 2017, 23, 1, 2, 14, 4, 78, 16, 2017, 5, 9, 2, 28, 4, 4, 2017, 5, 19, 37, 11, 12, 2017, 3, 18, 3, 2017, 7, 2017, 4, 2, 2017, 3, 118, 110, 8, 8, 1, 1, 1, 2017, 6, 9, 4, 12, 118, 110, 1, 33, 6, 2, 8, 6, 2017, 16, 1, 1, 2, 1, 2, 4, 4, 306, 12, 78, 10, 4, 306, 13, 16, 8, 306, 126, 25, 264, 2017, 2017, 13, 1, 2017, 126, 13, 35, 2017, 1, 1, 2, 5, 89, 211, 36, 2, 71, 10, 26, 2017, 211, 4, 2017, 211, 3, 306, 126, 306, 2, 2017, 2, 14, 2017, 211, 1, 2017, 5, 9, 3, 2017, 11, 2017, 9, 19, 2017, 6, 25, 1, 10, 31, 2017, 5, 9, 2017, 1, 2017, 126, 2017, 1, 5, 1, 5, 2017, 42, 1, 1, 4, 31, 25, 1, 1, 42, 6, 17, 2, 1, 306, 126, 306, 211, 3, 2017, 211, 12, 13, 2017, 264, 9, 2017, 15, 2017, 15, 78, 9, 118, 110, 26, 6, 2017, 5, 16, 2017, 2, 4, 1, 8, 21, 16, 2017, 2, 78, 7, 5, 5, 19, 264, 1, 4, 2017, 8, 9, 190, 4, 306, 8, 126, 306, 8, 1, 7, 35, 19, 85, 1, 34, 2017, 6, 3, 15, 4, 4, 10, 26, 85, 211, 5, 306, 264, 3, 28, 5, 1, 1, 85, 20, 70, 18, 7, 3, 1, 5, 2017, 5, 9, 2017, 85, 2017, 71, 2, 5, 3, 3, 7, 9, 2017, 71, 1, 16, 2017, 126, 2, 1, 5, 4, 8, 2, 89, 9, 78, 2017, 8, 1, 2017, 264, 4, 70, 26, 12, 26, 16, 18, 2017, 1, 67, 10, 1, 1, 2017, 8, 2, 1, 118, 110, 31, 54, 2017, 11, 71, 2, 30, 2, 3, 7, 306, 8, 7, 5, 7, 3, 85, 19, 3, 3, 306, 126, 2017, 6, 1, 67, 11, 4, 89, 1, 19, 85, 8, 2017, 2, 3, 2017, 1, 1, 1, 2, 1, 2017, 10, 5, 8, 16, 2017, 1, 2017, 1, 1, 2017, 1, 3, 36, 16, 15, 5, 11, 5, 67, 5, 8, 306, 126, 306, 54, 13, 1, 1, 29, 7, 16, 2017, 211, 4, 30, 211, 1, 2017, 211, 12, 2017, 5, 3, 1, 3, 2017, 1, 6, 9, 1, 2017, 3, 1, 42, 14, 4, 9, 306, 126, 9, 42, 2017, 4, 1, 2017, 1, 1, 42, 7, 6, 2, 2, 13, 15, 2017, 42, 2017, 1, 4, 1, 9, 5, 2017, 2, 306, 1, 1, 211, 7, 2, 3, 35, 6, 35, 6, 6, 306, 85, 126, 2017, 12, 35, 16, 85, 3, 1, 1, 1, 1, 1, 2017, 1, 1, 1, 1, 190, 3, 71, 2017, 1, 1, 2017, 1, 1, 85, 17, 9, 15, 2017, 126, 2017, 6, 2017, 2, 5, 11, 16, 8, 5, 211, 5, 5, 4, 1, 35, 2, 85, 211, 8, 1, 2, 2, 1, 1, 2017, 1, 264, 12, 2017, 1, 16, 85, 2, 7, 5, 2017, 4, 190, 3, 5, 30 ...
#
# Word_Frequencies
# [('Cape', 9), ('Canaveral', 8), (' ', 2017), ('coast', 4), (' ', 2017), ('spit', 2), ('land', 15), ('past', 8), ('Border', 18), ('Patrol', 3), ('checkpoint', 5), (' ', 2017), ('Rio', 9), ('Grande', 9), ('meets', 1), ('Gulf', 6), ('Mexico', 7), (' ', 2017), ('spaceship', 8), ('assembled', 4), ('State', 10), ('Highway', 14), ('4', 16), ('dead', 2), ('-', 190), ('ends', 1), ('sea', 11), ('Towering', 1), ('stainless', 6), ('-', 190), ('steel', 9), ('shiny', 1), (' ', 2017), ('looks', 3), ('like', 35), ('surreal', 2), ('sculpture', 1), ('amid', 2), ('cactuses', 1), (' ', 2017), ('yucca', 2), ('relentless', 1), ('South', 37), ('Texas', 76), ('sun', 5), (' ', 2017), (' ', 2017), ('s', 211), ('built', 11), ('factory', 2), ('open', 6), (' ', 2017), ('s', 211), ('roadside', 1), ('attraction', 2), (' ', 2017), ('drawing', 1), ('gawkers', 1), ('area', 28), ('remote', 2), ('county', 23), ('trucks', 7), ('drinking', 2), ('water', 14), ('month', 16), ('live', 9), ('nearby', 12), ('coming', 1), ('Elon', 19), ('Musk', 85), ('s', 211), ('latest', 5), ('creation', 1), (' ', 2017), ('prototype', 22), ('called', 12), ('Starship', 67), ('hopes', 2), ('day', 24), ('carry', 5), ('people', 30), ('dozens', 2), ('moon', 10), ('Mars', 26), (' ', 2017), ('Musk', 85), (' ', 2017), ('presentation', 5), ('Saturday', 5), (' ', 2017), ('said', 126), ('goal', 3), ('building', 16), (' ', 2017), ('rapidly', 2), ('reusable', 6), ('spacecraft', 15), (' ', 2017), ('lead', 1), ('fulfillment', 1), ('ultimate', 1), ('goal', 3), ('creating', 1), (' ', 2017), ('city', 6), ('Mars', 26), ('  ', 306), (' ', 2017), ('ll', 7), ('need', 6), ('pull', 1), ('improbable', 3), ('feat', 1), (' ', 2017), ('building', 16), ('private', 11), (' ', 2017), ('commercial', 14), ('spaceport', 11), (' ', 2017), ('local', 21), ('elected', 1), ('official', 5), ('called', 12), (' ', 2017), ('mind', 6), ('-', 190), ('boggling', 1), (' ', 2017), ('juxtaposition', 1), (':', 29), ('SpaceX', 264), (' ', 2017), ('hottest', 2), ('companies', 5), ('world', 10), (' ', 2017), ('led', 4), ('Silicon', 1), ('Valley', 6), ('celebrity', 1), ('nearly', 9), ('29', 9), ('million', 14), ('Twitter', 5), ('followers', 3), (' ', 2017), ('building', 16), ('rocket', 71), ('border', 11), ('town', 18), ('nearly', 9), ('residents', 78), ('live', 9), ('poverty', 1), ('line', 5), (' ', 2017), ('million', 14), ('years', 33), ('imagined', 3), ('  ', 306), ('said', 126), ('Cameron', 14), ('County', 14), ('Judge', 1), ('Eddie', 2), ('Treviño', 8), ('Jr', 1), (' ', 2017), ('years', 33), ('ago', 6), (' ', 2017), ('SpaceX', 264), ('started', 10), ('building', 16), ('launchpad', 6), (' ', 2017), ('hauling', 1), ('dirt', 3), ('ton', 1), (' ', 2017), ('allow', 7), ('company', 89), ('measure', 1), ('freedom', 2), ('restraints', 1), ('come', 17), ('shooting', 1), ('rockets', 18), ('government', 7), ('sites', 5), (' ', 2017), ('Cape', 9), ('Canaveral', 8), ('Vandenberg', 4), ('Air', 2), ('Force', 2), ('Base', 2), ('California', 5), (' ', 2017), ('companies', 5), ('operate', 2), ('  ', 306), ('going', 36), ('new', 54), ('kind', 8), ('spaceport', 11), ('optimized', 1), ('commercial', 14), ('operations', 12), ('  ', 306), ('Musk', 85), ('said', 126), ('groundbreaking', 2), ('ceremony', 2), ('2014', 15), ('  ', 306), ('Cape', 9), ('Canaveral', 8), ('Cape', 9), ('Vandenberg', 4), ('great', 3), ('launch', 70), ('sites', 5), (' ', 2017), ('military', 2), ('launch', 70), ('sites', 5), (' ', 2017), ('company', 89), ('welcomed', 1), ('local', 21), ('officials', 16), ('Walt', 1), ('Disney', 1), ('-', 190), ('like', 35), ('messiah', 1), ('help', 6), ('spark', 2), ('economic', 7), ('revival', 1), ('area', 28), ('desperately', 1), ('needs', 7), (' ', 2017), ('state', 14), ('set', 4), ('aside', 1), ('$', 25), ('15', 3), ('3', 10), ('million', 14), ('help', 6), ('company', 89), ('build', 15), ('facilities', 9), ('bought', 9), ('SpaceX', 264), ('s', 211), ('vision', 7), ('transform', 1), ('area', 28), ('commercial', 14), ('spaceport', 11), ('sending', 4 ...

# %%
#Word_Frequencies[word]= (Word_Frequencies[word]/maximum_frequency)

# %%
Word_Frequencies
# Out:
# '[(\'Cape\', 9), (\'Canaveral\', 8), (\' \', 2017), (\'coast\', 4), (\' \', 2017), (\'spit\', 2), (\'land\', 15), (\'past\', 8), (\'Border\', 18), (\'Patrol\', 3), (\'checkpoint\', 5), (\' \', 2017), (\'Rio\', 9), (\'Grande\', 9), (\'meets\', 1), (\'Gulf\', 6), (\'Mexico\', 7), (\' \', 2017), (\'spaceship\', 8), (\'assembled\', 4), (\'State\', 10), (\'Highway\', 14), (\'4\', 16), (\'dead\', 2), (\'-\', 190), (\'ends\', 1), (\'sea\', 11), (\'Towering\', 1), (\'stainless\', 6), (\'-\', 190), (\'steel\', 9), (\'shiny\', 1), (\' \', 2017), (\'looks\', 3), (\'like\', 35), (\'surreal\', 2), (\'sculpture\', 1), (\'amid\', 2), (\'cactuses\', 1), (\' \', 2017), (\'yucca\', 2), (\'relentless\', 1), (\'South\', 37), (\'Texas\', 76), (\'sun\', 5), (\' \', 2017), (\' \', 2017), (\'s\', 211), (\'built\', 11), (\'factory\', 2), (\'open\', 6), (\' \', 2017), (\'s\', 211), (\'roadside\', 1), (\'attraction\', 2), (\' \', 2017), (\'drawing\', 1), (\'gawkers\', 1), (\'area\', 28), (\'remote\', 2), (\'county\', 23), (\'trucks\', 7), (\'drinking\', 2), (\'water\', 14), (\'month\', 16), (\'live\', 9), (\'nearby\', 12), (\'coming\', 1), (\'Elon\', 19), (\'Musk\', 85), (\'s\', 211), (\'latest\', 5), (\'creation\', 1), (\' \', 2017), (\'prototype\', 22), (\'called\', 12), (\'Starship\', 67), (\'hopes\', 2), (\'day\', 24), (\'carry\', 5), (\'people\', 30), (\'dozens\', 2), (\'moon\', 10), (\'Mars\', 26), (\' \', 2017), (\'Musk\', 85), (\' \', 2017), (\'presentation\', 5), (\'Saturday\', 5), (\' \', 2017), (\'said\', 126), (\'goal\', 3), (\'building\', 16), (\' \', 2017), (\'rapidly\', 2), (\'reusable\', 6), (\'spacecraft\', 15), (\' \', 2017), (\'lead\', 1), (\'fulfillment\', 1), (\'ultimate\', 1), (\'goal\', 3), (\'creating\', 1), (\' \', 2017), (\'city\', 6), (\'Mars\', 26), (\'  \', 306), (\' \', 2017), (\'ll\', 7), (\'need\', 6), (\'pull\', 1), (\'improbable\', 3), (\'feat\', 1), (\' \', 2017), (\'building\', 16), (\'private\', 11), (\' \', 2017), (\'commercial\', 14), (\'spaceport\', 11), (\' \', 2017), (\'local\', 21), (\'elected\', 1), (\'official\', 5), (\'called\', 12), (\' \', 2017), (\'mind\', 6), (\'-\', 190), (\'boggling\', 1), (\' \', 2017), (\'juxtaposition\', 1), (\':\', 29), (\'SpaceX\', 264), (\' \', 2017), (\'hottest\', 2), (\'companies\', 5), (\'world\', 10), (\' \', 2017), (\'led\', 4), (\'Silicon\', 1), (\'Valley\', 6), (\'celebrity\', 1), (\'nearly\', 9), (\'29\', 9), (\'million\', 14), (\'Twitter\', 5), (\'followers\', 3), (\' \', 2017), (\'building\', 16), (\'rocket\', 71), (\'border\', 11), (\'town\', 18), (\'nearly\', 9), (\'residents\', 78), (\'live\', 9), (\'poverty\', 1), (\'line\', 5), (\' \', 2017), (\'million\', 14), (\'years\', 33), (\'imagined\', 3), (\'  \', 306), (\'said\', 126), (\'Cameron\', 14), (\'County\', 14), (\'Judge\', 1), (\'Eddie\', 2), (\'Treviño\', 8), (\'Jr\', 1), (\' \', 2017), (\'years\', 33), (\'ago\', 6), (\' \', 2017), (\'SpaceX\', 264), (\'started\', 10), (\'building\', 16), (\'launchpad\', 6), (\' \', 2017), (\'hauling\', 1), (\'dirt\', 3), (\'ton\', 1), (\' \', 2017), (\'allow\', 7), (\'company\', 89), (\'measure\', 1), (\'freedom\', 2), (\'restraints\', 1), (\'come\', 17), (\'shooting\', 1), (\'rockets\', 18), (\'government\', 7), (\'sites\', 5), (\' \', 2017), (\'Cape\', 9), (\'Canaveral\', 8), (\'Vandenberg\', 4), (\'Air\', 2), (\'Force\', 2), (\'Base\', 2), (\'California\', 5), (\' \', 2017), (\'companies\', 5), (\'operate\', 2), (\'  \', 306), (\'going\', 36), (\'new\', 54), (\'kind\', 8), (\'spaceport\', 11), (\'optimized\', 1), (\'commercial\', 14), (\'operations\', 12), (\'  \', 306), (\'Musk\', 85), (\'said\', 126), (\'groundbreaking\', 2), (\'ceremony\', 2), (\'2014\', 15), (\'  \', 306), (\'Cape\', 9), (\'Canaveral\', 8), (\'Cape\', 9), (\'Vandenberg\', 4), (\'great\', 3), (\'launch\', 70), (\'sites\', 5), (\' \', 2017), (\'military\', 2), (\'launch\', 70), (\'sites\', 5), (\' \', 2017), (\'company\', 89), (\'welcomed\', 1), (\'local\', 21), (\'officials\', 16), (\'Walt\', 1), (\'Disn ...

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
filtered_sentence

# %%
stopwords = nltk.corpus.stopwords.words('english')

word_frequencies = {}
for word in nltk.word_tokenize(mult):
    if word not in stopwords:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1

# %%
word_frequencies

# %%
maximum_frequncy = max(word_frequencies.values())

for word in word_frequencies.keys():
    word_frequencies[word] = (word_frequencies[word]/maximum_frequncy)

# %%
word_frequencies

# %% [markdown]
# Calculating Sentence Scores
#
# We have now calculated the weighted frequencies for all the words. Now is the time to calculate the scores for each sentence by adding weighted frequencies of the words that occur in that particular sentence. The following script calculates sentence scores:

# %%
sentence_scores = {}
for sent in token_list:
    for word in nltk.word_tokenize(sent.lower()):
        if word in word_frequencies.keys():
            if len(sent.split(' ')) < 30:
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word]
                else:
                    sentence_scores[sent] += word_frequencies[word]

# %%
sentence_scores

# %% [markdown]
# Getting the Summary
#
# Now we have the sentence_scores dictionary that contains sentences with their corresponding score. To summarize the article, we can take top N sentences with the highest scores. The following script retrieves top 7 sentences and prints them on the screen.

# %%
import heapq
summary_sentences = heapq.nlargest(7, sentence_scores, key=sentence_scores.get)

summary = ' '.join(summary_sentences)
print(summary)
# Out:
# said company residents would rocket launch one

# %%
#https://stackabuse.com/text-summarization-with-nltk-in-python/
#https://jcharistech.wordpress.com/2018/12/31/text-summarization-using-spacy-and-python/

# %%
# Convert Sentences from Spacy Span to Strings for joining entire sentence
for w in summary:
    print(w)

# %%
final_sentences = [ w for w in summary ]

# %%
final_sentences
# Out:
# ['s',
#  'a',
#  'i',
#  'd',
#  ' ',
#  'c',
#  'o',
#  'm',
#  'p',
#  'a',
#  'n',
#  'y',
#  ' ',
#  'r',
#  'e',
#  's',
#  'i',
#  'd',
#  'e',
#  'n',
#  't',
#  's',
#  ' ',
#  'w',
#  'o',
#  'u',
#  'l',
#  'd',
#  ' ',
#  'r',
#  'o',
#  'c',
#  'k',
#  'e',
#  't',
#  ' ',
#  'l',
#  'a',
#  'u',
#  'n',
#  'c',
#  'h',
#  ' ',
#  'o',
#  'n',
#  'e']

# %%
summary1 = ' '.join(final_sentences)

# %%
summary1
# Out:
# 's a i d   c o m p a n y   r e s i d e n t s   w o u l d   r o c k e t   l a u n c h   o n e'

# %%
len(summary1)
# Out:
# 91

# %%
len(file1)
# Out:
# 121226

# %%
from gensim.summarization import summarize

# %%
s=summarize(file1)

# %%
s
# Out:
# 'Cape Canaveral this is not.But here, down toward the coast, on a spit of land past the Border Patrol checkpoint, where the Rio Grande meets the Gulf of Mexico, there is a spaceship being assembled off State Highway 4 just before it dead-ends into the sea.Towering and stainless-steel shiny, it looks like a surreal sculpture amid the cactuses, yucca and relentless South Texas sun.\nAnd, because it’s being built not in a factory but out in the open, it’s become a roadside attraction, drawing gawkers to an area so remote that the county trucks in drinking water once a month to the few who live nearby.They’re coming to see Elon Musk’s latest creation, a prototype called Starship that he hopes will one day carry people by the dozens to the moon and Mars.\nMusk, in a presentation here Saturday, said his goal of building a “rapidly reusable spacecraft” here would lead to the fulfillment of his ultimate goal of creating “a city on Mars.” But first, he’ll need to pull off another improbable feat, building a private, commercial spaceport here, in what the top local elected official called a “mind-boggling” juxtaposition: SpaceX, one of the hottest companies in the world, led by a Silicon Valley celebrity with nearly 29 million Twitter followers, building a rocket in a border town where nearly a third of the residents live below the poverty line.“I never in a million years would have imagined it,” said Cameron County Judge Eddie Treviño Jr. Five years ago, SpaceX started building a launchpad here, hauling in dirt by the ton, that would allow the company a measure of freedom without the restraints that come with shooting rockets off from government sites, such as Cape Canaveral or Vandenberg Air Force Base in California, where several other companies operate.\nThe state set aside $15.3 million to help the company build its facilities here and has bought into SpaceX’s vision to transform the area into a commercial spaceport that would be sending people throughout the solar system.“You know the term ‘visionary’; they’re the ones who make the world go \'round,” Treviño said.\nBut now, across the water on South Padre Island, the county has spent about $31 million building new pavilions and an amphitheater that would host concerts and weddings and make a prime viewing area for rocket launches.\nLocal officials hope for a future where residents and tourists line the beach, the way they have for years along Florida’s Space Coast, cheering rockets as they tear through the sky.“It’s exciting,” said Sofia Benavides, a county commissioner who represents Boca Chica.\nA handful of residents who live next door to SpaceX’s facilities recently received letters from SpaceX, which said the company’s footprint in the area was going to be bigger and more disruptive than originally imagined.\nHe was trying to make his way to South Padre Island, the resort town just to the north but, instead, made a wrong turn, ended up in Boca Chica and decided he had found an oasis where he would plant his flag.\nHis neighbor Bonnie Heaton moved to Boca Chica 18 years ago from Minnesota with her husband after they retired.\nSpaceX is better than that.”While many of their neighbors, who don’t live in Boca Chica year round, have taken the offer, they continue to try to negotiate.To Treviño and other local officials, moving a few residents is a small price to pay to make way for SpaceX and its starry ambitions.“We have to think big-picture,” Treviño said.\n“And the fact that an individual with the vision like Elon Musk is investing his time, his money and his efforts to build his dream of launching to the moon and Mars here — it’s important that we be a part of that.” SpaceX chose the area because of its location and comparative desolation — you want to launch rockets near the equator and over unpopulated areas.\nAs for the rocket ranch he is building, he said it would continue to grow with more buildings and increased activity that forced the company to buy out residents’ prop ...

# %%
len(s)
# Out:
# 43866

# %% [markdown]
# Exercise 2. Sentiment Analysis
#
# What is the overall sentiment of the ‘spaceX.txt’ text? Provide the compound, negative,
# neutral, and positive metrics. Is the text more ‘subjective’ or more ‘objective’?
#
# DATA 690 Text Summarization spaCy Gensim.pdf

# %%
from textblob import TextBlob

# %%
analysis = TextBlob("“Mars is looking real,” he wrote in a series of tweets shortly after the flight, referring to his long-term goal of going to Mars to make humanity multiplanetary. “Progress is accelerating.”However, this test flight is months behind a schedule Musk set last September. “This thing is going to take off, fly to 65,000 feet, about 20 kilometers, and come back and land, in about one or two months,” he said at an event at Boca Chica, referring to a prototype known as Mark 1 standing behind him.That prototype, though, was destroyed in a tanking test last November. Three other Starship prototypes were destroyed in later tests, including the SN4 vehicle that exploded after a static-fire test May 29. At the event last September, Musk vowed to have reached orbit with the vehicle by now. “This is going to sound totally nuts, but I think we want to try to reach orbit in less than six months,” he said then, a schedule he thought to be “accurate to within a few months.”Around the time of that event, SpaceX was facing criticism from NASA for appearing to devote more attention to Starship than its Crew Dragon commercial crew vehicle, which the agency was counting on SpaceX to complete to enable the return of human orbital spaceflight to the United States.NASA Administrator Jim Bridenstine, in a tweet the day before that event last September, expressed his concerns bluntly. “Commercial Crew is years behind schedule. NASA expects to see the same level of enthusiasm focused on the investments of the American taxpayer. It’s time to deliver.”SpaceX did deliver with the Demo-2 mission, which successfully flew two NASA astronauts to the International Space Station and returned them to Earth Aug. 2 after a two-month mission. Bridenstine said he was pleased, recalling those earlier comments.“I want to tell you, Elon, you responded absolutely magnificently,” Bridenstine said at an Aug. 2 ceremony at Ellington Field, near the Johnson Space Center, to welcome back the astronauts. “You have delivered beyond anything any of us would have expected.” Musk was at the same event, calling the successful Demo-2 flight the beginning of a “new era in space exploration” that included going to the moon and Mars. “We’re going to go the moon. We’re going to have a base on the moon. We’re going to send people to Mars and make life multiplanetary,” he said. SpaceX hasn’t disclosed details about upcoming tests, although Federal Aviation Administration temporary flight restrictions to support hop tests remain in place through Aug. 6. “We’ll do several short hops to smooth out launch process, then go high altitude with body flaps,” Musk tweeted.")

# %%
analysis
# Out:
# TextBlob("“Mars is looking real,” he wrote in a series of tweets shortly after the flight, referring to his long-term goal of going to Mars to make humanity multiplanetary. “Progress is accelerating.”However, this test flight is months behind a schedule Musk set last September. “This thing is going to take off, fly to 65,000 feet, about 20 kilometers, and come back and land, in about one or two months,” he said at an event at Boca Chica, referring to a prototype known as Mark 1 standing behind him.That prototype, though, was destroyed in a tanking test last November. Three other Starship prototypes were destroyed in later tests, including the SN4 vehicle that exploded after a static-fire test May 29. At the event last September, Musk vowed to have reached orbit with the vehicle by now. “This is going to sound totally nuts, but I think we want to try to reach orbit in less than six months,” he said then, a schedule he thought to be “accurate to within a few months.”Around the time of that event, SpaceX was facing criticism from NASA for appearing to devote more attention to Starship than its Crew Dragon commercial crew vehicle, which the agency was counting on SpaceX to complete to enable the return of human orbital spaceflight to the United States.NASA Administrator Jim Bridenstine, in a tweet the day before that event last September, expressed his concerns bluntly. “Commercial Crew is years behind schedule. NASA expects to see the same level of enthusiasm focused on the investments of the American taxpayer. It’s time to deliver.”SpaceX did deliver with the Demo-2 mission, which successfully flew two NASA astronauts to the International Space Station and returned them to Earth Aug. 2 after a two-month mission. Bridenstine said he was pleased, recalling those earlier comments.“I want to tell you, Elon, you responded absolutely magnificently,” Bridenstine said at an Aug. 2 ceremony at Ellington Field, near the Johnson Space Center, to welcome back the astronauts. “You have delivered beyond anything any of us would have expected.” Musk was at the same event, calling the successful Demo-2 flight the beginning of a “new era in space exploration” that included going to the moon and Mars. “We’re going to go the moon. We’re going to have a base on the moon. We’re going to send people to Mars and make life multiplanetary,” he said. SpaceX hasn’t disclosed details about upcoming tests, although Federal Aviation Administration temporary flight restrictions to support hop tests remain in place through Aug. 6. “We’ll do several short hops to smooth out launch process, then go high altitude with body flaps,” Musk tweeted.")

# %%
print(dir(analysis))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_cmpkey', '_compare', '_create_sentence_objects', '_strkey', 'analyzer', 'classifier', 'classify', 'correct', 'detect_language', 'ends_with', 'endswith', 'find', 'format', 'index', 'join', 'json', 'lower', 'ngrams', 'noun_phrases', 'np_counts', 'np_extractor', 'parse', 'parser', 'polarity', 'pos_tagger', 'pos_tags', 'raw', 'raw_sentences', 'replace', 'rfind', 'rindex', 'sentences', 'sentiment', 'sentiment_assessments', 'serialized', 'split', 'starts_with', 'startswith', 'string', 'strip', 'stripped', 'subjectivity', 'tags', 'title', 'to_json', 'tokenize', 'tokenizer', 'tokens', 'translate', 'translator', 'upper', 'word_counts', 'words']

# %%
print(analysis.translate(to='es'))
# Out:
# "Marte parece real", escribió en una serie de tuits poco después del vuelo, refiriéndose a su objetivo a largo plazo de ir a Marte para hacer que la humanidad sea multiplanetaria. "El progreso se está acelerando". Sin embargo, este vuelo de prueba lleva meses de retraso con respecto al calendario establecido por Musk en septiembre pasado. "Esta cosa va a despegar, volar a 65.000 pies, unos 20 kilómetros, y volver y aterrizar, en uno o dos meses", dijo en un evento en Boca Chica, refiriéndose a un prototipo conocido como Mark 1 de pie. Sin embargo, ese prototipo fue destruido en una prueba de tanque en noviembre pasado. Otros tres prototipos de Starship fueron destruidos en pruebas posteriores, incluido el vehículo SN4 que explotó después de una prueba de fuego estático el 29 de mayo. En el evento de septiembre pasado, Musk prometió haber alcanzado la órbita con el vehículo ahora. "Esto va a sonar totalmente loco, pero creo que queremos intentar alcanzar la órbita en menos de seis meses", dijo entonces, un programa que pensó que sería "exacto en unos pocos meses". En el evento, SpaceX se enfrentaba a críticas de la NASA por parecer que dedicaba más atención a Starship que a su vehículo comercial Crew Dragon, que la agencia contaba con que SpaceX lo completara para permitir el regreso del vuelo espacial orbital humano a los Estados Unidos. , en un tuit el día antes de ese evento en septiembre pasado, expresó sin rodeos sus preocupaciones. “Commercial Crew lleva años de retraso. La NASA espera ver el mismo nivel de entusiasmo centrado en las inversiones del contribuyente estadounidense. Es hora de cumplir ”. SpaceX cumplió con la misión Demo-2, que llevó con éxito a dos astronautas de la NASA a la Estación Espacial Internacional y los devolvió a la Tierra el 2 de agosto después de una misión de dos meses. Bridenstine dijo que estaba complacido, recordando esos comentarios anteriores: "Quiero decirte, Elon, que respondiste absolutamente magníficamente", dijo Bridenstine en una ceremonia el 2 de agosto en Ellington Field, cerca del Centro Espacial Johnson, para dar la bienvenida a los astronautas. "Has cumplido más de lo que cualquiera de nosotros hubiera esperado". Musk estuvo en el mismo evento y calificó el exitoso vuelo Demo-2 como el comienzo de una "nueva era en la exploración espacial" que incluía ir a la Luna y Marte. "Vamos a ir a la luna. Tendremos una base en la luna. Vamos a enviar gente a Marte y hacer la vida multiplanetaria ”, dijo. SpaceX no ha revelado detalles sobre las próximas pruebas, aunque las restricciones temporales de vuelo de la Administración Federal de Aviación para respaldar las pruebas de salto permanecen vigentes hasta el 6 de agosto. ”, Tuiteó Musk.

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
print(analysis.tags)
# Out:
# [('“', 'JJ'), ('Mars', 'NNP'), ('is', 'VBZ'), ('looking', 'VBG'), ('real', 'JJ'), ('”', 'EX'), ('he', 'PRP'), ('wrote', 'VBD'), ('in', 'IN'), ('a', 'DT'), ('series', 'NN'), ('of', 'IN'), ('tweets', 'NNS'), ('shortly', 'RB'), ('after', 'IN'), ('the', 'DT'), ('flight', 'NN'), ('referring', 'VBG'), ('to', 'TO'), ('his', 'PRP$'), ('long-term', 'JJ'), ('goal', 'NN'), ('of', 'IN'), ('going', 'VBG'), ('to', 'TO'), ('Mars', 'NNP'), ('to', 'TO'), ('make', 'VB'), ('humanity', 'NN'), ('multiplanetary', 'NN'), ('“', 'JJ'), ('Progress', 'NNP'), ('is', 'VBZ'), ('accelerating.', 'JJ'), ('”', 'NNP'), ('However', 'RB'), ('this', 'DT'), ('test', 'NN'), ('flight', 'NN'), ('is', 'VBZ'), ('months', 'NNS'), ('behind', 'IN'), ('a', 'DT'), ('schedule', 'NN'), ('Musk', 'NNP'), ('set', 'VBD'), ('last', 'JJ'), ('September', 'NNP'), ('“', 'NN'), ('This', 'DT'), ('thing', 'NN'), ('is', 'VBZ'), ('going', 'VBG'), ('to', 'TO'), ('take', 'VB'), ('off', 'RP'), ('fly', 'NN'), ('to', 'TO'), ('65,000', 'CD'), ('feet', 'NNS'), ('about', 'RB'), ('20', 'CD'), ('kilometers', 'NNS'), ('and', 'CC'), ('come', 'VB'), ('back', 'RB'), ('and', 'CC'), ('land', 'NN'), ('in', 'IN'), ('about', 'IN'), ('one', 'CD'), ('or', 'CC'), ('two', 'CD'), ('months', 'NNS'), ('”', 'NN'), ('he', 'PRP'), ('said', 'VBD'), ('at', 'IN'), ('an', 'DT'), ('event', 'NN'), ('at', 'IN'), ('Boca', 'NNP'), ('Chica', 'NNP'), ('referring', 'VBG'), ('to', 'TO'), ('a', 'DT'), ('prototype', 'NN'), ('known', 'VBN'), ('as', 'IN'), ('Mark', 'NNP'), ('1', 'CD'), ('standing', 'VBG'), ('behind', 'IN'), ('him.That', 'WDT'), ('prototype', 'NN'), ('though', 'IN'), ('was', 'VBD'), ('destroyed', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('tanking', 'NN'), ('test', 'NN'), ('last', 'JJ'), ('November', 'NNP'), ('Three', 'CD'), ('other', 'JJ'), ('Starship', 'NNP'), ('prototypes', 'NNS'), ('were', 'VBD'), ('destroyed', 'VBN'), ('in', 'IN'), ('later', 'JJ'), ('tests', 'NNS'), ('including', 'VBG'), ('the', 'DT'), ('SN4', 'NNP'), ('vehicle', 'NN'), ('that', 'WDT'), ('exploded', 'VBD'), ('after', 'IN'), ('a', 'DT'), ('static-fire', 'JJ'), ('test', 'NN'), ('May', 'NNP'), ('29', 'CD'), ('At', 'IN'), ('the', 'DT'), ('event', 'NN'), ('last', 'JJ'), ('September', 'NNP'), ('Musk', 'NNP'), ('vowed', 'VBD'), ('to', 'TO'), ('have', 'VB'), ('reached', 'VBN'), ('orbit', 'NN'), ('with', 'IN'), ('the', 'DT'), ('vehicle', 'NN'), ('by', 'IN'), ('now', 'RB'), ('“', 'NN'), ('This', 'DT'), ('is', 'VBZ'), ('going', 'VBG'), ('to', 'TO'), ('sound', 'VB'), ('totally', 'RB'), ('nuts', 'JJ'), ('but', 'CC'), ('I', 'PRP'), ('think', 'VBP'), ('we', 'PRP'), ('want', 'VBP'), ('to', 'TO'), ('try', 'VB'), ('to', 'TO'), ('reach', 'VB'), ('orbit', 'NN'), ('in', 'IN'), ('less', 'JJR'), ('than', 'IN'), ('six', 'CD'), ('months', 'NNS'), ('”', 'NN'), ('he', 'PRP'), ('said', 'VBD'), ('then', 'RB'), ('a', 'DT'), ('schedule', 'NN'), ('he', 'PRP'), ('thought', 'VBD'), ('to', 'TO'), ('be', 'VB'), ('“', 'JJ'), ('accurate', 'NN'), ('to', 'TO'), ('within', 'IN'), ('a', 'DT'), ('few', 'JJ'), ('months.', 'NN'), ('”', 'NN'), ('Around', 'IN'), ('the', 'DT'), ('time', 'NN'), ('of', 'IN'), ('that', 'DT'), ('event', 'NN'), ('SpaceX', 'NNP'), ('was', 'VBD'), ('facing', 'VBG'), ('criticism', 'NN'), ('from', 'IN'), ('NASA', 'NNP'), ('for', 'IN'), ('appearing', 'VBG'), ('to', 'TO'), ('devote', 'VB'), ('more', 'JJR'), ('attention', 'NN'), ('to', 'TO'), ('Starship', 'NNP'), ('than', 'IN'), ('its', 'PRP$'), ('Crew', 'NNP'), ('Dragon', 'NNP'), ('commercial', 'JJ'), ('crew', 'NN'), ('vehicle', 'NN'), ('which', 'WDT'), ('the', 'DT'), ('agency', 'NN'), ('was', 'VBD'), ('counting', 'VBG'), ('on', 'IN'), ('SpaceX', 'NNP'), ('to', 'TO'), ('complete', 'VB'), ('to', 'TO'), ('enable', 'VB'), ('the', 'DT'), ('return', 'NN'), ('of', 'IN'), ('human', 'JJ'), ('orbital', 'JJ'), ('spaceflight', 'NN'), ('to', 'TO'), ('the', 'DT'), ('United', 'NNP'), ('States.NASA', 'NNP'), ('Administrator', 'NNP'), ('Jim', 'NNP'), ('Bridenstine', 'NNP'), ('in', 'IN'), ('a', 'DT'), ('tweet', 'NN'), ('the', 'DT'), ('day', 'NN') ...

# %%
print(analysis.sentiment)
# Out:
# Sentiment(polarity=0.10010923185341793, subjectivity=0.3822374911909796)

# %%
from textblob import TextBlob

pos_count = 0
pos_correct = 0

with open("positive.txt","r") as f:
    for line in f.read().split('\n'):
        analysis = TextBlob(line)
        if analysis.sentiment.polarity > 0:
            pos_correct += 1
        pos_count +=1


neg_count = 0
neg_correct = 0

with open("negative.txt","r") as f:
    for line in f.read().split('\n'):
        analysis = TextBlob(line)
        if analysis.sentiment.polarity <= 0:
            neg_correct += 1
        neg_count +=1

print("Positive accuracy = {}% via {} samples".format(pos_correct/pos_count*100.0, pos_count))
print("Negative accuracy = {}% via {} samples".format(neg_correct/neg_count*100.0, neg_count))
# Out:
# Positive accuracy = 71.13111986494091% via 5331 samples
# Negative accuracy = 55.861939598574374% via 5331 samples

# %%
        if analysis.sentiment.polarity > 0.2:
            pos_correct += 1

# %%
if analysis.sentiment.polarity <= 0.2:
            neg_correct += 1

# %%
from textblob import TextBlob

pos_count = 0
pos_correct = 0

with open("positive.txt","r") as f:
    for line in f.read().split('\n'):
        analysis = TextBlob(line)

        if analysis.sentiment.subjectivity < 0.3:
            if analysis.sentiment.polarity > 0:
                pos_correct += 1
            pos_count +=1


neg_count = 0
neg_correct = 0

with open("negative.txt","r") as f:
    for line in f.read().split('\n'):
        analysis = TextBlob(line)
        if analysis.sentiment.subjectivity < 0.3:
            if analysis.sentiment.polarity <= 0:
                neg_correct += 1
            neg_count +=1

print("Positive accuracy = {}% via {} samples".format(pos_correct/pos_count*100.0, pos_count))
print("Negative accuracy = {}% via {} samples".format(neg_correct/neg_count*100.0, neg_count))
# Out:
# Positive accuracy = 29.145728643216078% via 995 samples
# Negative accuracy = 76.01532567049809% via 1305 samples

# %%
from textblob import TextBlob

pos_count = 0
pos_correct = 0

with open("positive.txt","r") as f:
    for line in f.read().split('\n'):
        analysis = TextBlob(line)

        if analysis.sentiment.subjectivity > 0.9:
            if analysis.sentiment.polarity > 0:
                pos_correct += 1
            pos_count +=1


neg_count = 0
neg_correct = 0

with open("negative.txt","r") as f:
    for line in f.read().split('\n'):
        analysis = TextBlob(line)
        if analysis.sentiment.subjectivity > 0.9:
            if analysis.sentiment.polarity <= 0:
                neg_correct += 1
            neg_count +=1

print("Positive accuracy = {}% via {} samples".format(pos_correct/pos_count*100.0, pos_count))
print("Negative accuracy = {}% via {} samples".format(neg_correct/neg_count*100.0, neg_count))
# Out:
# Positive accuracy = 76.08695652173914% via 414 samples
# Negative accuracy = 68.6046511627907% via 344 samples

# %%
pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/76/fc/310e16254683c1ed35eeb97386986d6c00bc29df17ce280aed64d55537e9/vaderSentiment-3.3.2-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 2.6MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (1.24.3)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()
vs = analyzer.polarity_scores("VADER Sentiment looks interesting, I have high hopes!")
print(vs)
# Out:
# {'neg': 0.0, 'neu': 0.509, 'pos': 0.491, 'compound': 0.6996}

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

pos_count = 0
pos_correct = 0

with open("positive.txt","r") as f:
    for line in f.read().split('\n'):
        vs = analyzer.polarity_scores(line)
        if vs['compound'] > 0:
            pos_correct += 1
        pos_count +=1


neg_count = 0
neg_correct = 0

with open("negative.txt","r") as f:
    for line in f.read().split('\n'):
        vs = analyzer.polarity_scores(line)
        if vs['compound'] <= 0:
            neg_correct += 1
        neg_count +=1

print("Positive accuracy = {}% via {} samples".format(pos_correct/pos_count*100.0, pos_count))
print("Negative accuracy = {}% via {} samples".format(neg_correct/neg_count*100.0, neg_count))
# Out:
# Positive accuracy = 70.19320952916901% via 5331 samples
# Negative accuracy = 57.38135434252486% via 5331 samples

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

pos_count = 0
pos_correct = 0

threshold = 0.5

with open("positive.txt","r") as f:
    for line in f.read().split('\n'):
        vs = analyzer.polarity_scores(line)

        if vs['compound'] >= threshold or vs['compound'] <= -threshold:
            if vs['compound'] > 0:
                pos_correct += 1
            pos_count +=1


neg_count = 0
neg_correct = 0

with open("negative.txt","r") as f:
    for line in f.read().split('\n'):
        vs = analyzer.polarity_scores(line)
        if vs['compound'] >= threshold or vs['compound'] <= -threshold:
            if vs['compound'] <= 0:
                neg_correct += 1
            neg_count +=1

print("Positive accuracy = {}% via {} samples".format(pos_correct/pos_count*100.0, pos_count))
print("Negative accuracy = {}% via {} samples".format(neg_correct/neg_count*100.0, neg_count))
# Out:
# Positive accuracy = 87.66037735849056% via 2650 samples
# Negative accuracy = 49.56140350877193% via 1824 samples

# %%
if not vs['neg'] > 0.1:
  if vs['pos']-vs['neg'] >= 0:
    pos_correct += 1
  pos_count +=1

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

import time
analyzer = SentimentIntensityAnalyzer()

pos_count = 0
pos_correct = 0

with open("positive.txt","r") as f:
    for line in f.read().split('\n'):
        vs = analyzer.polarity_scores(line)
        if not vs['neg'] > 0.1:
            if vs['pos']-vs['neg'] > 0:
                pos_correct += 1
            pos_count +=1


neg_count = 0
neg_correct = 0

with open("negative.txt","r") as f:
    for line in f.read().split('\n'):
        vs = analyzer.polarity_scores(line)
        if not vs['pos'] > 0.1:
            if vs['pos']-vs['neg'] <= 0:
                neg_correct += 1
            neg_count +=1

print("Positive accuracy = {}% via {} samples".format(pos_correct/pos_count*100.0, pos_count))
print("Negative accuracy = {}% via {} samples".format(neg_correct/neg_count*100.0, neg_count))
# Out:
# Positive accuracy = 81.05006105006105% via 4095 samples
# Negative accuracy = 89.26495726495727% via 2925 samples

# %%
from textblob import TextBlob

pos_count = 0
pos_correct = 0

with open("positive.txt","r") as f:
    for line in f.read().split('\n'):
        analysis = TextBlob(line)

        if analysis.sentiment.polarity >= 0.5:
            if analysis.sentiment.polarity > 0:
                pos_correct += 1
            pos_count +=1


neg_count = 0
neg_correct = 0

with open("negative.txt","r") as f:
    for line in f.read().split('\n'):
        analysis = TextBlob(line)
        if analysis.sentiment.polarity <= -0.5:
            if analysis.sentiment.polarity <= 0:
                neg_correct += 1
            neg_count +=1

print("Positive accuracy = {}% via {} samples".format(pos_correct/pos_count*100.0, pos_count))
print("Negative accuracy = {}% via {} samples".format(neg_correct/neg_count*100.0, neg_count))
# Out:
# Positive accuracy = 100.0% via 766 samples
# Negative accuracy = 100.0% via 282 samples
